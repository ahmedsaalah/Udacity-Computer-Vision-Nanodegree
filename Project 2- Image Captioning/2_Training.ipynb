# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:**
#  For Encoding step CNN, resnet50 pretrained remove the last layet and replace with an embedding layer that has the same number of neurons as the embed_size to fed into the RNN In the Rnn Decoding step i've used the word embedding followed Lstm and the lastly linear layer .
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:** I use the default transform train
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set params to something like:
#
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
#
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:** Next, you will specify a Python list containing the learnable parameters of the model. For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set params to something like:
#
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:** Adam the reason that from practice and as well as from blogs and research ofi've found that step size of Adam update rule is invariant to the magnitude of the gradient, which helps a lot when going through areas with tiny gradients . In these areas SGD struggles to quickly navigate through them.

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 64          # batch size
vocab_threshold = 4        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 512           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 5            # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters())

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params = params, lr = 0.001)


# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=0.83s)
# creating index...
#   0%|          | 879/414113 [00:00<01:37, 4223.60it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:27<00:00, 4713.96it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/5], Step [100/6471], Loss: 3.7754, Perplexity: 43.6161
# Epoch [1/5], Step [200/6471], Loss: 3.6086, Perplexity: 36.91437
# Epoch [1/5], Step [300/6471], Loss: 3.1415, Perplexity: 23.13809
# Epoch [1/5], Step [400/6471], Loss: 3.1423, Perplexity: 23.1573
# Epoch [1/5], Step [500/6471], Loss: 2.8863, Perplexity: 17.9276
# Epoch [1/5], Step [600/6471], Loss: 3.1825, Perplexity: 24.1075
# Epoch [1/5], Step [700/6471], Loss: 2.9899, Perplexity: 19.8845
# Epoch [1/5], Step [800/6471], Loss: 2.8114, Perplexity: 16.6325
# Epoch [1/5], Step [900/6471], Loss: 2.7857, Perplexity: 16.2118
# Epoch [1/5], Step [1000/6471], Loss: 2.6196, Perplexity: 13.7297
# Epoch [1/5], Step [1100/6471], Loss: 2.7147, Perplexity: 15.1007
# Epoch [1/5], Step [1200/6471], Loss: 2.5396, Perplexity: 12.6749
# Epoch [1/5], Step [1300/6471], Loss: 2.5690, Perplexity: 13.0526
# Epoch [1/5], Step [1400/6471], Loss: 2.9441, Perplexity: 18.99325
# Epoch [1/5], Step [1500/6471], Loss: 2.4552, Perplexity: 11.6483
# Epoch [1/5], Step [1600/6471], Loss: 2.3529, Perplexity: 10.5157
# Epoch [1/5], Step [1700/6471], Loss: 2.4056, Perplexity: 11.0847
# Epoch [1/5], Step [1800/6471], Loss: 2.5273, Perplexity: 12.5200
# Epoch [1/5], Step [1900/6471], Loss: 2.8450, Perplexity: 17.2007
# Epoch [1/5], Step [2000/6471], Loss: 2.2690, Perplexity: 9.67016
# Epoch [1/5], Step [2100/6471], Loss: 2.5186, Perplexity: 12.4116
# Epoch [1/5], Step [2200/6471], Loss: 2.6421, Perplexity: 14.0433
# Epoch [1/5], Step [2300/6471], Loss: 2.4870, Perplexity: 12.0250
# Epoch [1/5], Step [2400/6471], Loss: 2.2958, Perplexity: 9.93194
# Epoch [1/5], Step [2500/6471], Loss: 2.2683, Perplexity: 9.66317
# Epoch [1/5], Step [2600/6471], Loss: 2.4500, Perplexity: 11.5882
# Epoch [1/5], Step [2700/6471], Loss: 2.3151, Perplexity: 10.1256
# Epoch [1/5], Step [2800/6471], Loss: 2.2539, Perplexity: 9.52505
# Epoch [1/5], Step [2900/6471], Loss: 2.2779, Perplexity: 9.75663
# Epoch [1/5], Step [3000/6471], Loss: 2.5206, Perplexity: 12.43585
# Epoch [1/5], Step [3100/6471], Loss: 2.4302, Perplexity: 11.3609
# Epoch [1/5], Step [3200/6471], Loss: 2.3458, Perplexity: 10.4416
# Epoch [1/5], Step [3300/6471], Loss: 2.3315, Perplexity: 10.2934
# Epoch [1/5], Step [3400/6471], Loss: 2.2283, Perplexity: 9.28366
# Epoch [1/5], Step [3500/6471], Loss: 2.0504, Perplexity: 7.77105
# Epoch [1/5], Step [3600/6471], Loss: 2.3034, Perplexity: 10.0086
# Epoch [1/5], Step [3700/6471], Loss: 2.2576, Perplexity: 9.56012
# Epoch [1/5], Step [3800/6471], Loss: 2.2762, Perplexity: 9.73994
# Epoch [1/5], Step [3900/6471], Loss: 2.4289, Perplexity: 11.3467
# Epoch [1/5], Step [4000/6471], Loss: 2.2820, Perplexity: 9.79615
# Epoch [1/5], Step [4100/6471], Loss: 2.4048, Perplexity: 11.0765
# Epoch [1/5], Step [4200/6471], Loss: 2.2668, Perplexity: 9.64826
# Epoch [1/5], Step [4300/6471], Loss: 3.1842, Perplexity: 24.1482
# Epoch [1/5], Step [4400/6471], Loss: 2.1704, Perplexity: 8.76204
# Epoch [1/5], Step [4500/6471], Loss: 2.4858, Perplexity: 12.0104
# Epoch [1/5], Step [4600/6471], Loss: 2.2944, Perplexity: 9.91867
# Epoch [1/5], Step [4700/6471], Loss: 2.2473, Perplexity: 9.46238
# Epoch [1/5], Step [4800/6471], Loss: 2.1813, Perplexity: 8.85827
# Epoch [1/5], Step [4900/6471], Loss: 2.5564, Perplexity: 12.8891
# Epoch [1/5], Step [5000/6471], Loss: 2.1604, Perplexity: 8.67458
# Epoch [1/5], Step [5100/6471], Loss: 2.1726, Perplexity: 8.78111
# Epoch [1/5], Step [5200/6471], Loss: 2.1383, Perplexity: 8.48485
# Epoch [1/5], Step [5300/6471], Loss: 2.3443, Perplexity: 10.4262
# Epoch [1/5], Step [5400/6471], Loss: 2.0183, Perplexity: 7.52546
# Epoch [1/5], Step [5500/6471], Loss: 2.3752, Perplexity: 10.75273
# Epoch [1/5], Step [5600/6471], Loss: 2.0377, Perplexity: 7.67330
# Epoch [1/5], Step [5700/6471], Loss: 2.3643, Perplexity: 10.6361
# Epoch [1/5], Step [5800/6471], Loss: 2.2571, Perplexity: 9.55520
# Epoch [1/5], Step [5900/6471], Loss: 1.9315, Perplexity: 6.90005
# Epoch [1/5], Step [6000/6471], Loss: 2.7962, Perplexity: 16.3817
# Epoch [1/5], Step [6100/6471], Loss: 2.0386, Perplexity: 7.68021
# Epoch [1/5], Step [6200/6471], Loss: 2.2764, Perplexity: 9.74193
# Epoch [1/5], Step [6300/6471], Loss: 2.2717, Perplexity: 9.69630
# Epoch [1/5], Step [6400/6471], Loss: 2.2392, Perplexity: 9.38597
# Epoch [2/5], Step [100/6471], Loss: 2.4071, Perplexity: 11.10160
# Epoch [2/5], Step [200/6471], Loss: 2.8511, Perplexity: 17.3065
# Epoch [2/5], Step [300/6471], Loss: 1.9640, Perplexity: 7.12787
# Epoch [2/5], Step [400/6471], Loss: 2.1420, Perplexity: 8.51643
# Epoch [2/5], Step [500/6471], Loss: 2.1540, Perplexity: 8.61967
# Epoch [2/5], Step [600/6471], Loss: 2.2690, Perplexity: 9.66962
# Epoch [2/5], Step [700/6471], Loss: 2.1904, Perplexity: 8.93904
# Epoch [2/5], Step [800/6471], Loss: 1.8184, Perplexity: 6.16212
# Epoch [2/5], Step [900/6471], Loss: 2.1847, Perplexity: 8.88800
# Epoch [2/5], Step [1000/6471], Loss: 2.3415, Perplexity: 10.3973
# Epoch [2/5], Step [1100/6471], Loss: 2.8814, Perplexity: 17.8384
# Epoch [2/5], Step [1200/6471], Loss: 2.1114, Perplexity: 8.25943
# Epoch [2/5], Step [1300/6471], Loss: 2.0583, Perplexity: 7.83265
# Epoch [2/5], Step [1400/6471], Loss: 2.2231, Perplexity: 9.23565
# Epoch [2/5], Step [1500/6471], Loss: 2.3622, Perplexity: 10.6139
# Epoch [2/5], Step [1600/6471], Loss: 2.2828, Perplexity: 9.80399
# Epoch [2/5], Step [1700/6471], Loss: 2.1045, Perplexity: 8.20294
# Epoch [2/5], Step [1800/6471], Loss: 1.9825, Perplexity: 7.26110
# Epoch [2/5], Step [1900/6471], Loss: 2.0815, Perplexity: 8.01636
# Epoch [2/5], Step [2000/6471], Loss: 2.0083, Perplexity: 7.45096
# Epoch [2/5], Step [2100/6471], Loss: 2.1034, Perplexity: 8.19446
# Epoch [2/5], Step [2200/6471], Loss: 2.1465, Perplexity: 8.55461
# Epoch [2/5], Step [2300/6471], Loss: 2.1170, Perplexity: 8.30583
# Epoch [2/5], Step [2400/6471], Loss: 2.0857, Perplexity: 8.05019
# Epoch [2/5], Step [2500/6471], Loss: 1.8837, Perplexity: 6.57751
# Epoch [2/5], Step [2600/6471], Loss: 1.9588, Perplexity: 7.09083
# Epoch [2/5], Step [2700/6471], Loss: 2.4384, Perplexity: 11.4545
# Epoch [2/5], Step [2800/6471], Loss: 1.9330, Perplexity: 6.91016
# Epoch [2/5], Step [2900/6471], Loss: 2.0554, Perplexity: 7.81021
# Epoch [2/5], Step [3000/6471], Loss: 1.9579, Perplexity: 7.08423
# Epoch [2/5], Step [3100/6471], Loss: 1.9412, Perplexity: 6.96691
# Epoch [2/5], Step [3200/6471], Loss: 2.3771, Perplexity: 10.7741
# Epoch [2/5], Step [3300/6471], Loss: 1.9801, Perplexity: 7.24340
# Epoch [2/5], Step [3400/6471], Loss: 2.3832, Perplexity: 10.8400
# Epoch [2/5], Step [3500/6471], Loss: 2.1259, Perplexity: 8.38024
# Epoch [2/5], Step [3600/6471], Loss: 1.8418, Perplexity: 6.30779
# Epoch [2/5], Step [3700/6471], Loss: 2.1698, Perplexity: 8.75683
# Epoch [2/5], Step [3800/6471], Loss: 2.1339, Perplexity: 8.44808
# Epoch [2/5], Step [3900/6471], Loss: 1.9925, Perplexity: 7.33401
# Epoch [2/5], Step [4000/6471], Loss: 2.1647, Perplexity: 8.71168
# Epoch [2/5], Step [4100/6471], Loss: 1.9900, Perplexity: 7.31545
# Epoch [2/5], Step [4200/6471], Loss: 2.0008, Perplexity: 7.39532
# Epoch [2/5], Step [4300/6471], Loss: 1.9247, Perplexity: 6.85349
# Epoch [2/5], Step [4400/6471], Loss: 2.0002, Perplexity: 7.39058
# Epoch [2/5], Step [4500/6471], Loss: 2.0108, Perplexity: 7.46937
# Epoch [2/5], Step [4600/6471], Loss: 1.9355, Perplexity: 6.92767
# Epoch [2/5], Step [4700/6471], Loss: 1.9900, Perplexity: 7.31533
# Epoch [2/5], Step [4800/6471], Loss: 2.0927, Perplexity: 8.10702
# Epoch [2/5], Step [4900/6471], Loss: 1.9640, Perplexity: 7.12780
# Epoch [2/5], Step [5000/6471], Loss: 2.5355, Perplexity: 12.6227
# Epoch [2/5], Step [5100/6471], Loss: 2.2447, Perplexity: 9.43742
# Epoch [2/5], Step [5200/6471], Loss: 1.9660, Perplexity: 7.14188
# Epoch [2/5], Step [5300/6471], Loss: 1.9377, Perplexity: 6.94318
# Epoch [2/5], Step [5400/6471], Loss: 1.9555, Perplexity: 7.06751
# Epoch [2/5], Step [5500/6471], Loss: 2.0210, Perplexity: 7.54569
# Epoch [2/5], Step [5600/6471], Loss: 2.0663, Perplexity: 7.89592
# Epoch [2/5], Step [5700/6471], Loss: 2.2248, Perplexity: 9.25178
# Epoch [2/5], Step [5800/6471], Loss: 2.1538, Perplexity: 8.61717
# Epoch [2/5], Step [5900/6471], Loss: 2.1644, Perplexity: 8.70986
# Epoch [2/5], Step [6000/6471], Loss: 1.9843, Perplexity: 7.27392
# Epoch [2/5], Step [6100/6471], Loss: 2.1513, Perplexity: 8.59627
# Epoch [2/5], Step [6200/6471], Loss: 1.7998, Perplexity: 6.04871
# Epoch [2/5], Step [6300/6471], Loss: 1.9173, Perplexity: 6.80291
# Epoch [2/5], Step [6400/6471], Loss: 2.0639, Perplexity: 7.87673
# Epoch [3/5], Step [100/6471], Loss: 2.6276, Perplexity: 13.84126
# Epoch [3/5], Step [200/6471], Loss: 2.3069, Perplexity: 10.0434
# Epoch [3/5], Step [300/6471], Loss: 1.8804, Perplexity: 6.55591
# Epoch [3/5], Step [400/6471], Loss: 2.0681, Perplexity: 7.90997
# Epoch [3/5], Step [500/6471], Loss: 1.8104, Perplexity: 6.11305
# Epoch [3/5], Step [600/6471], Loss: 1.8125, Perplexity: 6.12595
# Epoch [3/5], Step [700/6471], Loss: 2.1072, Perplexity: 8.22536
# Epoch [3/5], Step [800/6471], Loss: 1.9727, Perplexity: 7.18984
# Epoch [3/5], Step [900/6471], Loss: 2.1781, Perplexity: 8.82911
# Epoch [3/5], Step [1000/6471], Loss: 2.3253, Perplexity: 10.2297
# Epoch [3/5], Step [1100/6471], Loss: 1.9555, Perplexity: 7.06780
# Epoch [3/5], Step [1200/6471], Loss: 1.8515, Perplexity: 6.36966
# Epoch [3/5], Step [1300/6471], Loss: 1.9923, Perplexity: 7.33235
# Epoch [3/5], Step [1400/6471], Loss: 1.9724, Perplexity: 7.18762
# Epoch [3/5], Step [1500/6471], Loss: 1.8429, Perplexity: 6.31503
# Epoch [3/5], Step [1600/6471], Loss: 2.3009, Perplexity: 9.98312
# Epoch [3/5], Step [1700/6471], Loss: 2.1962, Perplexity: 8.99100
# Epoch [3/5], Step [1800/6471], Loss: 1.9695, Perplexity: 7.16718
# Epoch [3/5], Step [1900/6471], Loss: 2.0310, Perplexity: 7.62167
# Epoch [3/5], Step [2000/6471], Loss: 1.9290, Perplexity: 6.88239
# Epoch [3/5], Step [2100/6471], Loss: 1.9250, Perplexity: 6.85502
# Epoch [3/5], Step [2200/6471], Loss: 2.0131, Perplexity: 7.48699
# Epoch [3/5], Step [2300/6471], Loss: 1.9570, Perplexity: 7.07800
# Epoch [3/5], Step [2400/6471], Loss: 1.9610, Perplexity: 7.10676
# Epoch [3/5], Step [2500/6471], Loss: 1.9152, Perplexity: 6.78800
# Epoch [3/5], Step [2600/6471], Loss: 1.8478, Perplexity: 6.345773
# Epoch [3/5], Step [2700/6471], Loss: 1.9981, Perplexity: 7.37517
# Epoch [3/5], Step [2800/6471], Loss: 2.0172, Perplexity: 7.517562
# Epoch [3/5], Step [2900/6471], Loss: 2.1842, Perplexity: 8.88341
# Epoch [3/5], Step [3000/6471], Loss: 2.0635, Perplexity: 7.87380
# Epoch [3/5], Step [3100/6471], Loss: 2.1422, Perplexity: 8.51831
# Epoch [3/5], Step [3200/6471], Loss: 1.8174, Perplexity: 6.15597
# Epoch [3/5], Step [3300/6471], Loss: 1.9665, Perplexity: 7.14539
# Epoch [3/5], Step [3400/6471], Loss: 2.9914, Perplexity: 19.9134
# Epoch [3/5], Step [3500/6471], Loss: 2.2616, Perplexity: 9.59841
# Epoch [3/5], Step [3600/6471], Loss: 1.9169, Perplexity: 6.80018
# Epoch [3/5], Step [3700/6471], Loss: 2.2886, Perplexity: 9.86140
# Epoch [3/5], Step [3800/6471], Loss: 1.8980, Perplexity: 6.67266
# Epoch [3/5], Step [3900/6471], Loss: 1.9304, Perplexity: 6.89216
# Epoch [3/5], Step [4000/6471], Loss: 1.9562, Perplexity: 7.07254
# Epoch [3/5], Step [4100/6471], Loss: 1.8113, Perplexity: 6.11847
# Epoch [3/5], Step [4200/6471], Loss: 1.9401, Perplexity: 6.95976
# Epoch [3/5], Step [4300/6471], Loss: 2.0162, Perplexity: 7.509437
# Epoch [3/5], Step [4400/6471], Loss: 2.0512, Perplexity: 7.77694
# Epoch [3/5], Step [4500/6471], Loss: 1.9199, Perplexity: 6.82006
# Epoch [3/5], Step [4600/6471], Loss: 1.9526, Perplexity: 7.04674
# Epoch [3/5], Step [4700/6471], Loss: 1.8776, Perplexity: 6.53802
# Epoch [3/5], Step [4800/6471], Loss: 1.8426, Perplexity: 6.31327
# Epoch [3/5], Step [4900/6471], Loss: 2.0161, Perplexity: 7.50922
# Epoch [3/5], Step [5000/6471], Loss: 1.6650, Perplexity: 5.28559
# Epoch [3/5], Step [5100/6471], Loss: 1.8293, Perplexity: 6.22943
# Epoch [3/5], Step [5200/6471], Loss: 1.8760, Perplexity: 6.52709
# Epoch [3/5], Step [5300/6471], Loss: 1.9591, Perplexity: 7.09275
# Epoch [3/5], Step [5400/6471], Loss: 1.7878, Perplexity: 5.97659
# Epoch [3/5], Step [5500/6471], Loss: 2.2838, Perplexity: 9.81436
# Epoch [3/5], Step [5600/6471], Loss: 2.2442, Perplexity: 9.43311
# Epoch [3/5], Step [5700/6471], Loss: 1.8846, Perplexity: 6.58348
# Epoch [3/5], Step [5800/6471], Loss: 2.1227, Perplexity: 8.35403
# Epoch [3/5], Step [5900/6471], Loss: 2.1136, Perplexity: 8.27770
# Epoch [3/5], Step [6000/6471], Loss: 2.0276, Perplexity: 7.59551
# Epoch [3/5], Step [6100/6471], Loss: 1.8972, Perplexity: 6.66738
# Epoch [3/5], Step [6200/6471], Loss: 1.8134, Perplexity: 6.13131
# Epoch [3/5], Step [6300/6471], Loss: 2.0546, Perplexity: 7.80375
# Epoch [3/5], Step [6400/6471], Loss: 1.9362, Perplexity: 6.93233
# Epoch [4/5], Step [100/6471], Loss: 1.8380, Perplexity: 6.284024
# Epoch [4/5], Step [200/6471], Loss: 1.9449, Perplexity: 6.99318
# Epoch [4/5], Step [300/6471], Loss: 1.7420, Perplexity: 5.70909
# Epoch [4/5], Step [400/6471], Loss: 1.8987, Perplexity: 6.67700
# Epoch [4/5], Step [500/6471], Loss: 1.8989, Perplexity: 6.67838
# Epoch [4/5], Step [600/6471], Loss: 1.9212, Perplexity: 6.82959
# Epoch [4/5], Step [700/6471], Loss: 1.8448, Perplexity: 6.32653
# Epoch [4/5], Step [800/6471], Loss: 2.0647, Perplexity: 7.88262
# Epoch [4/5], Step [900/6471], Loss: 1.9555, Perplexity: 7.06741
# Epoch [4/5], Step [1000/6471], Loss: 2.2631, Perplexity: 9.6124
# Epoch [4/5], Step [1100/6471], Loss: 1.7190, Perplexity: 5.57894
# Epoch [4/5], Step [1200/6471], Loss: 1.9908, Perplexity: 7.32134
# Epoch [4/5], Step [1300/6471], Loss: 1.9712, Perplexity: 7.17919
# Epoch [4/5], Step [1400/6471], Loss: 1.6989, Perplexity: 5.46779
# Epoch [4/5], Step [1500/6471], Loss: 1.8527, Perplexity: 6.37722
# Epoch [4/5], Step [1600/6471], Loss: 2.2623, Perplexity: 9.60503
# Epoch [4/5], Step [1700/6471], Loss: 1.9887, Perplexity: 7.30570
# Epoch [4/5], Step [1800/6471], Loss: 1.9514, Perplexity: 7.03840
# Epoch [4/5], Step [1900/6471], Loss: 1.9849, Perplexity: 7.27817
# Epoch [4/5], Step [2000/6471], Loss: 1.8984, Perplexity: 6.67528
# Epoch [4/5], Step [2100/6471], Loss: 2.0345, Perplexity: 7.64853
# Epoch [4/5], Step [2200/6471], Loss: 1.8191, Perplexity: 6.16644
# Epoch [4/5], Step [2300/6471], Loss: 1.7734, Perplexity: 5.89108
# Epoch [4/5], Step [2400/6471], Loss: 1.8558, Perplexity: 6.39679
# Epoch [4/5], Step [2500/6471], Loss: 1.9222, Perplexity: 6.83603
# Epoch [4/5], Step [2600/6471], Loss: 2.0870, Perplexity: 8.06054
# Epoch [4/5], Step [2700/6471], Loss: 2.0584, Perplexity: 7.83365
# Epoch [4/5], Step [2800/6471], Loss: 1.9433, Perplexity: 6.98172
# Epoch [4/5], Step [2900/6471], Loss: 1.9324, Perplexity: 6.90617
# Epoch [4/5], Step [3000/6471], Loss: 1.9734, Perplexity: 7.19535
# Epoch [4/5], Step [3100/6471], Loss: 1.8414, Perplexity: 6.30549
# Epoch [4/5], Step [3200/6471], Loss: 1.7359, Perplexity: 5.67395
# Epoch [4/5], Step [3300/6471], Loss: 2.7137, Perplexity: 15.0849
# Epoch [4/5], Step [3400/6471], Loss: 2.1065, Perplexity: 8.21979
# Epoch [4/5], Step [3500/6471], Loss: 1.8473, Perplexity: 6.34291
# Epoch [4/5], Step [3600/6471], Loss: 2.0362, Perplexity: 7.66189
# Epoch [4/5], Step [3700/6471], Loss: 1.8450, Perplexity: 6.32808
# Epoch [4/5], Step [3800/6471], Loss: 1.8987, Perplexity: 6.67712
# Epoch [4/5], Step [3900/6471], Loss: 1.9268, Perplexity: 6.86761
# Epoch [4/5], Step [4000/6471], Loss: 1.8723, Perplexity: 6.50338
# Epoch [4/5], Step [4100/6471], Loss: 1.7384, Perplexity: 5.68848
# Epoch [4/5], Step [4200/6471], Loss: 1.8456, Perplexity: 6.33184
# Epoch [4/5], Step [4300/6471], Loss: 1.8900, Perplexity: 6.61940
# Epoch [4/5], Step [4400/6471], Loss: 1.9101, Perplexity: 6.75391
# Epoch [4/5], Step [4500/6471], Loss: 1.8555, Perplexity: 6.39518
# Epoch [4/5], Step [4600/6471], Loss: 1.9387, Perplexity: 6.94964
# Epoch [4/5], Step [4700/6471], Loss: 1.7173, Perplexity: 5.56960
# Epoch [4/5], Step [4800/6471], Loss: 2.0369, Perplexity: 7.66666
# Epoch [4/5], Step [4900/6471], Loss: 1.9005, Perplexity: 6.68957
# Epoch [4/5], Step [5000/6471], Loss: 1.6893, Perplexity: 5.41569
# Epoch [4/5], Step [5100/6471], Loss: 1.9069, Perplexity: 6.73206
# Epoch [4/5], Step [5200/6471], Loss: 1.9445, Perplexity: 6.98998
# Epoch [4/5], Step [5300/6471], Loss: 1.8748, Perplexity: 6.51986
# Epoch [4/5], Step [5400/6471], Loss: 2.1365, Perplexity: 8.470159
# Epoch [4/5], Step [5500/6471], Loss: 1.7889, Perplexity: 5.98262
# Epoch [4/5], Step [5700/6471], Loss: 1.8499, Perplexity: 6.35917
# Epoch [4/5], Step [5800/6471], Loss: 1.8230, Perplexity: 6.19031
# Epoch [4/5], Step [5900/6471], Loss: 2.1787, Perplexity: 8.83518
# Epoch [4/5], Step [6000/6471], Loss: 1.9688, Perplexity: 7.16206
# Epoch [4/5], Step [6100/6471], Loss: 2.0919, Perplexity: 8.10028
# Epoch [4/5], Step [6200/6471], Loss: 1.8697, Perplexity: 6.48656
# Epoch [4/5], Step [6300/6471], Loss: 2.5986, Perplexity: 13.4451
# Epoch [4/5], Step [6400/6471], Loss: 2.0419, Perplexity: 7.70542
# Epoch [5/5], Step [100/6471], Loss: 2.0071, Perplexity: 7.441943
# Epoch [5/5], Step [200/6471], Loss: 2.0507, Perplexity: 7.77336
# Epoch [5/5], Step [300/6471], Loss: 1.7365, Perplexity: 5.67725
# Epoch [5/5], Step [400/6471], Loss: 1.9019, Perplexity: 6.69878
# Epoch [5/5], Step [500/6471], Loss: 1.8196, Perplexity: 6.16921
# Epoch [5/5], Step [600/6471], Loss: 1.9687, Perplexity: 7.16159
# Epoch [5/5], Step [700/6471], Loss: 1.8556, Perplexity: 6.39563
# Epoch [5/5], Step [800/6471], Loss: 1.7769, Perplexity: 5.91150
# Epoch [5/5], Step [900/6471], Loss: 1.8605, Perplexity: 6.42696
# Epoch [5/5], Step [1000/6471], Loss: 1.9825, Perplexity: 7.2610
# Epoch [5/5], Step [1100/6471], Loss: 1.7281, Perplexity: 5.62985
# Epoch [5/5], Step [1200/6471], Loss: 1.8767, Perplexity: 6.53220
# Epoch [5/5], Step [1300/6471], Loss: 2.5638, Perplexity: 12.9846
# Epoch [5/5], Step [1400/6471], Loss: 2.0112, Perplexity: 7.47230
# Epoch [5/5], Step [1500/6471], Loss: 1.9253, Perplexity: 6.85697
# Epoch [5/5], Step [1600/6471], Loss: 1.9512, Perplexity: 7.03726
# Epoch [5/5], Step [1700/6471], Loss: 1.9244, Perplexity: 6.85118
# Epoch [5/5], Step [1800/6471], Loss: 1.7644, Perplexity: 5.83828
# Epoch [5/5], Step [1900/6471], Loss: 1.9179, Perplexity: 6.80640
# Epoch [5/5], Step [2000/6471], Loss: 1.9349, Perplexity: 6.92304
# Epoch [5/5], Step [2100/6471], Loss: 1.8492, Perplexity: 6.35474
# Epoch [5/5], Step [2200/6471], Loss: 1.9722, Perplexity: 7.18645
# Epoch [5/5], Step [2300/6471], Loss: 1.7928, Perplexity: 6.00633
# Epoch [5/5], Step [2400/6471], Loss: 1.8859, Perplexity: 6.5923
# Epoch [5/5], Step [2500/6471], Loss: 1.6529, Perplexity: 5.22216
# Epoch [5/5], Step [2600/6471], Loss: 1.7751, Perplexity: 5.90079
# Epoch [5/5], Step [2700/6471], Loss: 2.2116, Perplexity: 9.13000
# Epoch [5/5], Step [2800/6471], Loss: 1.7662, Perplexity: 5.84886
# Epoch [5/5], Step [2900/6471], Loss: 1.9109, Perplexity: 6.75946
# Epoch [5/5], Step [3000/6471], Loss: 1.9306, Perplexity: 6.89408
# Epoch [5/5], Step [3100/6471], Loss: 2.0497, Perplexity: 7.76563
# Epoch [5/5], Step [3200/6471], Loss: 1.8298, Perplexity: 6.23252
# Epoch [5/5], Step [3300/6471], Loss: 1.8228, Perplexity: 6.18933
# Epoch [5/5], Step [3400/6471], Loss: 1.6817, Perplexity: 5.37455
# Epoch [5/5], Step [3500/6471], Loss: 1.6676, Perplexity: 5.29938
# Epoch [5/5], Step [3600/6471], Loss: 2.0244, Perplexity: 7.57151
# Epoch [5/5], Step [3700/6471], Loss: 1.8107, Perplexity: 6.11497
# Epoch [5/5], Step [3800/6471], Loss: 1.7681, Perplexity: 5.85981
# Epoch [5/5], Step [3900/6471], Loss: 1.8367, Perplexity: 6.27572
# Epoch [5/5], Step [4000/6471], Loss: 1.8328, Perplexity: 6.25147
# Epoch [5/5], Step [4100/6471], Loss: 1.7468, Perplexity: 5.73608
# Epoch [5/5], Step [4200/6471], Loss: 1.8565, Perplexity: 6.40134
# Epoch [5/5], Step [4300/6471], Loss: 1.8141, Perplexity: 6.13569
# Epoch [5/5], Step [4347/6471], Loss: 1.7608, Perplexity: 5.81693

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
